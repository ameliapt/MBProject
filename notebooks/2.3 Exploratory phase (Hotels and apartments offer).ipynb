# %% [markdown]
# # Spain's turism industry dashboard
#
# ### Exploratory Data Analysis III

# %% [markdown]
# Libraries.

# %%
from functions import describe_df
from functions import create_histograms
from functions import create_boxplots
from functions import detect_outliers

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Hotels

# %% [markdown]
# #### Statistic: Pernoctaciones por puntos turísticos

# %%
file_name = 'hotels_nights.xlsx'
path = 'C:/Users/ameli/IRONHACK/WEEK_5/MBP/data/clean/'

hotels_nights = pd.read_excel(path+file_name)
hotels_nights = hotels_nights.drop('Unnamed: 0', axis=1)
hotels_nights.head()
# Out:
#      tourist_point  value                origin       date
# 0  Vitoria-Gastéiz  38807  Residentes en España 2022-06-01
# 1  Vitoria-Gastéiz  39187  Residentes en España 2022-05-01
# 2  Vitoria-Gastéiz  39147  Residentes en España 2022-04-01
# 3  Vitoria-Gastéiz  36476  Residentes en España 2022-03-01
# 4  Vitoria-Gastéiz  30212  Residentes en España 2022-02-01

# %%
hotels_nights_summary = describe_df(hotels_nights)
# Out:
# Shape of dataframe is:
# (13955, 4)
#
# Data types of dataframe are:
# tourist_point            object
# value                     int64
# origin                   object
# date             datetime64[ns]
# dtype: object
#
# Summary of numeric data is:
#          count          mean            std  min     25%      50%      75%  \
# value  13955.0  65739.541956  165551.925129  0.0  2646.0  15331.0  47813.0
#
#              max
# value  2013312.0
#
# Summary of categorical data is:
#                count unique                   top  freq
# tourist_point  13955    106       Vitoria-Gastéiz   132
# origin         13955      2  Residentes en España  6991
#
# Does it contain missing values?
# tourist_point    0
# value            0
# origin           0
# date             0
# dtype: int64
#
# Value counts:
# Vitoria-Gastéiz               132
# Murcia                        132
# Gandía                        132
# Toledo                        132
# Teruel                        132
# ...

# %%
hotels_nights_hist = create_histograms(hotels_nights, 'tourist_point', 'value')

# %%
hotels_nights_boxplot = create_boxplots(hotels_nights, 'tourist_point', 'value')
# Out:
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
results_hotels_nights = pd.crosstab(index= hotels_nights.tourist_point, columns = hotels_nights.origin, values = hotels_nights.value, dropna = True, aggfunc = 'mean')
display(round(results_hotels_nights))
# Out:
# origin                      Residentes en España  Residentes en el extranjero
# tourist_point
# Adeje                                    57604.0                     599096.0
# Albacete                                 19702.0                       3419.0
# Albarracín                                5149.0                        694.0
# Algeciras                                11947.0                      10238.0
# Alicante                                 55785.0                      74117.0
# Almería                                  38067.0                      15295.0
# Antequera                                 7398.0                       3989.0
# Arcos de la Frontera                      3976.0                       1774.0
# Arona                                    30163.0                     337743.0
# Badajoz                                  18017.0                       4393.0
# Barcelona                               191911.0                    1060576.0
# ...

# %% [markdown]
# #### Statistic: Establecimientos, plazas estimadas, grados de ocupación y personal empleado por puntos turísticos

# %%
file_name = 'hotels_overview.xlsx'
path = 'C:/Users/ameli/IRONHACK/WEEK_5/MBP/data/clean/'

hotels_overview = pd.read_excel(path+file_name)
hotels_overview = hotels_overview.drop('Unnamed: 0', axis=1)
hotels_overview.head()
# Out:
#      tourist_point                                       category  value  \
# 0  Vitoria-Gasteiz  Número de establecimientos abiertos estimados   39.0
# 1  Vitoria-Gasteiz  Número de establecimientos abiertos estimados   39.0
# 2  Vitoria-Gasteiz  Número de establecimientos abiertos estimados   39.0
# 3  Vitoria-Gasteiz  Número de establecimientos abiertos estimados   39.0
# 4  Vitoria-Gasteiz  Número de establecimientos abiertos estimados   39.0
#
#         date
# 0 2022-06-01
# 1 2022-05-01
# 2 2022-04-01
# 3 2022-03-01
# 4 2022-02-01

# %%
hotels_overview_summary = describe_df(hotels_overview)
# Out:
# Shape of dataframe is:
# (48972, 4)
#
# Data types of dataframe are:
# tourist_point            object
# category                 object
# value                   float64
# date             datetime64[ns]
# dtype: object
#
# Summary of numeric data is:
#          count         mean          std  min    25%    50%    75%      max
# value  48972.0  1646.363041  5892.238841  0.0  29.06  65.68  783.0  89514.0
#
# Summary of categorical data is:
#                count unique                                            top  \
# tourist_point  48972    106                                Vitoria-Gasteiz
# category       48972      7  Número de establecimientos abiertos estimados
#
#                freq
# tourist_point   462
# category       6996
#
# Does it contain missing values?
# tourist_point    0
# category         0
# value            0
# date             0
# dtype: int64
#
# Value counts:
# Vitoria-Gasteiz    462
# Sitges             462
# Capdepera          462
# ...

# %%
hotels_overview_results = pd.crosstab(index= hotels_overview.tourist_point, columns = hotels_overview.category, values = hotels_overview.value, aggfunc = 'mean')
display(round(hotels_overview_results))
# Out:
# category                    Grado de ocupación por habitaciones  \
# tourist_point
# Adeje                                                      69.0
# Albacete                                                   45.0
# Albarracín                                                 34.0
# Algeciras                                                  46.0
# Alicante                                                   62.0
# Almería                                                    60.0
# Antequera                                                  32.0
# Arcos de la Frontera                                       25.0
# Arona                                                      69.0
# Badajoz                                                    43.0
# Barcelona                                                  62.0
# Benalmádena                                                61.0
# Benasque                                                   39.0
# ...

# %% [markdown]
# #### Statistic: Tarifa media (ADR) por puntos turísticos

# %%
file_name = 'hotels_adr.xlsx'
path = 'C:/Users/ameli/IRONHACK/WEEK_5/MBP/data/clean/'

hotels_adr = pd.read_excel(path+file_name)
hotels_adr = hotels_adr.drop('Unnamed: 0', axis=1)
hotels_adr.head()
# Out:
#      tourist_point  value       date
# 0  Vitoria-Gasteiz  70.88 2022-06-01
# 1  Vitoria-Gasteiz  63.04 2022-05-01
# 2  Vitoria-Gasteiz  64.57 2022-04-01
# 3  Vitoria-Gasteiz  57.89 2022-03-01
# 4  Vitoria-Gasteiz  52.50 2022-02-01

# %%
hotels_adr_summary = describe_df(hotels_adr)
# Out:
# Shape of dataframe is:
# (1908, 3)
#
# Data types of dataframe are:
# tourist_point            object
# value                   float64
# date             datetime64[ns]
# dtype: object
#
# Summary of numeric data is:
#         count       mean       std  min      25%    50%      75%     max
# value  1908.0  69.617117  34.44518  0.0  53.5625  65.58  83.3925  358.02
#
# Summary of categorical data is:
#               count unique              top freq
# tourist_point  1908    106  Vitoria-Gasteiz   18
#
# Does it contain missing values?
# tourist_point    0
# value            0
# date             0
# dtype: int64
#
# Value counts:
# Vitoria-Gasteiz                18
# Tías                           18
# San Bartolomé de Tirajana      18
# Palmas de Gran Canaria, Las    18
# Pájara                         18
#                                ..
# Ciudad Real                    18
# Peníscola/Peñíscola            18
# Castelló de la Plana           18
# Tarifa                         18
# ...

# %%
hotels_adr_r = pd.crosstab(index= hotels_adr.tourist_point, columns = hotels_adr.date, values = hotels_adr.value, aggfunc = 'mean')
display(round(hotels_adr_r))
# Out:
# date           2021-01-01  2021-02-01  2021-03-01  2021-04-01  2021-05-01  \
# tourist_point
# Adeje               136.0       152.0       151.0       153.0       127.0
# Albacete             44.0        45.0        45.0        48.0        48.0
# Albarracín            0.0        62.0        48.0        49.0        52.0
# Algeciras             0.0         0.0        59.0        55.0        58.0
# Alicante             54.0        52.0        58.0        62.0        67.0
# ...                   ...         ...         ...         ...         ...
# Viveiro               0.0         0.0        54.0        62.0        69.0
# Yaiza                75.0        71.0        77.0        80.0        74.0
# Zamora               44.0        40.0        43.0        48.0        52.0
# Zaragoza             45.0        48.0        48.0        48.0        52.0
# Ávila                38.0        37.0        43.0        44.0        47.0
#
# ...

# %% [markdown]
# ##### Top 10 tourist points by ADR

# %%
hotels_adr.nlargest(n=10, columns=['value'])
# Out:
#      tourist_point   value       date
# 862      Naut Aran  358.02 2021-02-01
# 860      Naut Aran  308.06 2021-04-01
# 1090      Marbella  253.63 2021-08-01
# 1036      Estepona  241.76 2021-08-01
# 1091      Marbella  224.01 2021-07-01
# 1037      Estepona  222.64 2021-07-01
# 850      Naut Aran  217.91 2022-02-01
# 1094      Marbella  217.89 2021-04-01
# 1080      Marbella  217.72 2022-06-01
# 1086      Marbella  201.31 2021-12-01

# %% [markdown]
# #### Statistic: Índice de ingresos hoteleros, índices y tasas de variación interanual

# %%
file_name = 'hotels_revenue.xlsx'
path = 'C:/Users/ameli/IRONHACK/WEEK_5/MBP/data/clean/'

hotels_revenue = pd.read_excel(path+file_name)
hotels_revenue = hotels_revenue.drop('Unnamed: 0', axis=1)
hotels_revenue.head()
# Out:
#   tourist_point  value       date
# 0      Nacional  95.09 2009-12-01
# 1      Nacional  94.23 2009-11-01
# 2      Nacional  94.03 2009-10-01
# 3      Nacional  94.14 2009-09-01
# 4      Nacional  95.55 2009-08-01

# %%
hotels_revenue_summary = describe_df(hotels_revenue)
# Out:
# Shape of dataframe is:
# (1200, 3)
#
# Data types of dataframe are:
# tourist_point            object
# value                   float64
# date             datetime64[ns]
# dtype: object
#
# Summary of numeric data is:
#         count       mean       std    min    25%    50%    75%     max
# value  1200.0  96.493175  4.081161  76.67  93.74  97.39  100.0  109.07
#
# Summary of categorical data is:
#               count unique       top freq
# tourist_point  1200     20  Nacional   60
#
# Does it contain missing values?
# tourist_point    0
# value            0
# date             0
# dtype: int64
#
# Value counts:
# Nacional                        60
# Andalucía                       60
# Ceuta                           60
# Rioja (La)                      60
# País Vasco                      60
# Navarra (Comunidad Foral de)    60
# Murcia (Región de)              60
# Madrid (Comunidad de)           60
# Galicia                         60
# Extremadura                     60
# ...

# %%
hotels_rev_results = pd.crosstab(index= hotels_revenue.tourist_point, columns = hotels_revenue.date, values = hotels_revenue.value, aggfunc = 'mean')
display(round(hotels_rev_results))
# Out:
# date                          2005-01-01  2005-02-01  2005-03-01  2005-04-01  \
# tourist_point
# Andalucía                           96.0        97.0        96.0        95.0
# Aragón                              92.0        89.0        91.0        90.0
# Asturias (Principado de)            91.0        89.0        94.0        88.0
# Balears (Illes)                     90.0        88.0        87.0        90.0
# Canarias                            96.0        97.0        95.0        95.0
# Cantabria                           99.0        94.0        97.0        88.0
# Castilla - La Mancha                90.0        92.0        93.0        88.0
# Castilla y León                     94.0        93.0        95.0        91.0
# Cataluña                            93.0        89.0        93.0        91.0
# Ceuta                               88.0        87.0        92.0        90.0
# Comunitat Valenciana                95.0        95.0        93.0        90.0
# ...

# %%
hotels_adr.nlargest(n=10, columns=['value'])
# Out:
#      tourist_point   value       date
# 862      Naut Aran  358.02 2021-02-01
# 860      Naut Aran  308.06 2021-04-01
# 1090      Marbella  253.63 2021-08-01
# 1036      Estepona  241.76 2021-08-01
# 1091      Marbella  224.01 2021-07-01
# 1037      Estepona  222.64 2021-07-01
# 850      Naut Aran  217.91 2022-02-01
# 1094      Marbella  217.89 2021-04-01
# 1080      Marbella  217.72 2022-06-01
# 1086      Marbella  201.31 2021-12-01

# %% [markdown]
# ### Turistic apartments
#
# #### Statistic:  Pernoctaciones por puntos turísticos

# %%
file_name = 'apart_nights.xlsx'
path = 'C:/Users/ameli/IRONHACK/WEEK_5/MBP/data/clean/'

apart_nights = pd.read_excel(path+file_name)
apart_nights = apart_nights.drop('Unnamed: 0', axis = 1)
apart_nights.head()
# Out:
#        tourist_point                origin  value       date
# 0  Alfas Del Pi (L )  Residentes en España      0 2022-06-01
# 1  Alfas Del Pi (L )  Residentes en España      0 2022-05-01
# 2  Alfas Del Pi (L )  Residentes en España      0 2022-04-01
# 3  Alfas Del Pi (L )  Residentes en España   3362 2022-03-01
# 4  Alfas Del Pi (L )  Residentes en España   2910 2022-02-01

# %%
apart_nights_summary = describe_df(apart_nights)
# Out:
# Shape of dataframe is:
# (8580, 4)
#
# Data types of dataframe are:
# tourist_point            object
# origin                   object
# value                     int64
# date             datetime64[ns]
# dtype: object
#
# Summary of numeric data is:
#         count          mean           std  min    25%     50%       75%  \
# value  8580.0  22980.642541  56328.656987  0.0  309.0  4063.0  18597.25
#
#             max
# value  584545.0
#
# Summary of categorical data is:
#               count unique                   top  freq
# tourist_point  8580     65     Alfas Del Pi (L )   132
# origin         8580      2  Residentes en España  4290
#
# Does it contain missing values?
# tourist_point    0
# origin           0
# value            0
# date             0
# dtype: int64
#
# Value counts:
# Alfas Del Pi (L )            132
# San Bartolomé De Tirajana    132
# Tias                         132
# Yaiza                        132
# Adeje                        132
# ...

# %%
results_apart_nights = pd.crosstab(index= apart_nights.tourist_point, columns = apart_nights.origin, values = apart_nights.value, dropna = True, aggfunc = 'mean')
display(round(results_apart_nights))
# Out:
# origin             Residentes en España  Residentes en el extranjero
# tourist_point
# Adeje                           13972.0                     170902.0
# Alajero                           523.0                        692.0
# Alfas Del Pi (L )                2236.0                       6806.0
# Alicante/Alacant                12959.0                      16904.0
# Almuñecar                        6660.0                       2865.0
# ...                                 ...                          ...
# Valencia                        20396.0                      39558.0
# Valle Gran Rey                   6110.0                      14830.0
# Vitoria-Gasteiz                  4001.0                        950.0
# Yaiza                            4493.0                      56963.0
# Zaragoza                         4424.0                       2424.0
#
# [65 rows x 2 columns]

# %%
apart_nights_hist = create_histograms(apart_nights, 'tourist_point','value')

# %%
apart_nights_boxplot = create_boxplots(apart_nights, 'tourist_point','value')
# Out:
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
fig, ax = plt.subplots(dpi=100)
ax = sns.lineplot(data= apart_nights, x= 'date', y = 'value', hue = 'tourist_point', style = 'tourist_point')
ax = plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

# %%
fig, ax = plt.subplots(dpi=100)
ax = sns.lineplot(data= apart_nights, x= 'date', y = 'value', hue = 'origin', style = 'origin')
ax = plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

# %% [markdown]
# #### Statistic: Plazas, apartamentos, grados de ocupación y personal empleado por puntos turísticos

# %%
file_name = 'apart_overview.xlsx'
path = 'C:/Users/ameli/IRONHACK/WEEK_5/MBP/data/clean/'

apart_overview = pd.read_excel(path+file_name)
apart_overview = apart_overview.drop('Unnamed: 0', axis=1)
apart_overview.head()
# Out:
#    index      tourist_point  \
# 0      0  Alfas Del Pi (L )
# 1      1  Alfas Del Pi (L )
# 2      2  Alfas Del Pi (L )
# 3      3  Alfas Del Pi (L )
# 4      4  Alfas Del Pi (L )
#
#                                             category  value       date
# 0  Grado de ocupación por apartamentos en fin de ...   0.00 2022-06-01
# 1  Grado de ocupación por apartamentos en fin de ...   0.00 2022-05-01
# 2  Grado de ocupación por apartamentos en fin de ...   0.00 2022-04-01
# 3  Grado de ocupación por apartamentos en fin de ...  52.08 2022-03-01
# 4  Grado de ocupación por apartamentos en fin de ...  36.03 2022-02-01

# %%
apart_overview_summary = describe_df(apart_overview)
# Out:
# Shape of dataframe is:
# (25740, 5)
#
# Data types of dataframe are:
# index                     int64
# tourist_point            object
# category                 object
# value                   float64
# date             datetime64[ns]
# dtype: object
#
# Summary of numeric data is:
#          count          mean          std  min      25%       50%       75%  \
# index  25740.0  12869.500000  7430.642301  0.0  6434.75  12869.50  19304.25
# value  25740.0    865.695632  2724.261729  0.0    14.39     58.53    327.00
#
#            max
# index  25739.0
# value  37736.0
#
# Summary of categorical data is:
#                count unique  \
# tourist_point  25740     65
# category       25740      6
#
#                                                              top  freq
# tourist_point                                  Alfas Del Pi (L )   396
# category       Grado de ocupación por apartamentos en fin de ...  4290
#
# Does it contain missing values?
# index            0
# ...

# %%
apart_overview_boxplots = create_boxplots(apart_overview, 'category' ,'value')
# Out:
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
apart_overview_hist= create_histograms(apart_overview, 'category' ,'value')

# %%
apart_overview_results = pd.crosstab(index= apart_overview.tourist_point, columns = apart_overview.category, values = apart_overview.value, aggfunc = 'mean')
display(round(apart_overview_results))
# Out:
# category           Grado de ocupación por apartamentos  \
# tourist_point
# Adeje                                             66.0
# Alajero                                           26.0
# Alfas Del Pi (L )                                 17.0
# Alicante/Alacant                                  47.0
# Almuñecar                                         43.0
# ...                                                ...
# Valencia                                          58.0
# Valle Gran Rey                                    47.0
# Vitoria-Gasteiz                                   63.0
# Yaiza                                             64.0
# Zaragoza                                          59.0
#
# category           Grado de ocupación por apartamentos en fin de semana  \
# tourist_point
# Adeje                                                           67.0
# Alajero                                                         28.0
# ...

# %% [markdown]
# #### Statistic: Índice de precios de apartamentos (IPAP): índice general nacional y desglose por modalidades

# %%
file_name = 'ipap_mod.xlsx'
path = 'C:/Users/ameli/IRONHACK/WEEK_5/MBP/data/clean/'

ipap_mod = pd.read_excel(path+file_name)
ipap_mod = ipap_mod.drop('Unnamed: 0', axis=1)
ipap_mod.head()
# Out:
#             category   value       date
# 0  Total modalidades  159.83 2022-06-01
# 1  Total modalidades  188.44 2022-05-01
# 2  Total modalidades  157.63 2022-04-01
# 3  Total modalidades  132.17 2022-03-01
# 4  Total modalidades  133.25 2022-02-01

# %%
ipap_mod_summary = describe_df(ipap_mod)
# Out:
# Shape of dataframe is:
# (840, 3)
#
# Data types of dataframe are:
# category            object
# value              float64
# date        datetime64[ns]
# dtype: object
#
# Summary of numeric data is:
#        count        mean        std  min       25%     50%       75%     max
# value  840.0  121.553583  19.523789  0.0  107.7975  116.47  132.8825  200.12
#
# Summary of categorical data is:
#          count unique                top freq
# category   840      4  Total modalidades  210
#
# Does it contain missing values?
# category    0
# value       0
# date        0
# dtype: int64
#
# Value counts:
# Total modalidades             210
# Estudio                       210
# Apartamentos de 2/4 plazas    210
# Apartamentos de 4/6 plazas    210
# Name: category, dtype: int64
#
# 131.80    4
# 0.00      4
# 134.89    3
# 107.36    3
# 108.24    3
#          ..
# 145.94    1
# 118.25    1
# 114.85    1
# 115.20    1
# 102.02    1
# Name: value, Length: 765, dtype: int64
#
# ...

# %%
ipap_mod_boxplots = create_boxplots(ipap_mod, 'category', 'value')
# Out:
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
ipap_mod_hist = create_histograms(ipap_mod, 'category', 'value')

# %%
ipap_mod_results = pd.crosstab(index= ipap_mod.category, columns = ipap_mod.date, values = ipap_mod.value, aggfunc = 'mean')
display(round(ipap_mod_results))
# Out:
# date                        2005-01-01  2005-02-01  2005-03-01  2005-04-01  \
# category
# Apartamentos de 2/4 plazas       100.0        99.0       100.0        98.0
# Apartamentos de 4/6 plazas       102.0       102.0       106.0       101.0
# Estudio                           99.0       101.0       103.0       102.0
# Total modalidades                100.0       100.0       101.0        99.0
#
# date                        2005-05-01  2005-06-01  2005-07-01  2005-08-01  \
# category
# Apartamentos de 2/4 plazas       101.0       104.0       108.0       107.0
# Apartamentos de 4/6 plazas       105.0       107.0       109.0       111.0
# Estudio                          104.0       102.0       107.0       106.0
# Total modalidades                102.0       104.0       108.0       108.0
#
# date                        2005-09-01  2005-10-01  ...  2021-09-01  \
# category                                            ...
# ...

# %%
fig, ax = plt.subplots(dpi=200)
ax = sns.lineplot(data= ipap_mod, x= 'date', y = 'value', hue = 'category', style = 'category')
ax = plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

# %% [markdown]
# #### Statistic: Índice de precios de apartamentos (IPAP): índice general nacional y desglose por tarifas

# %%
file_name = 'ipap_rate.xlsx'
path = 'C:/Users/ameli/IRONHACK/WEEK_5/MBP/data/clean/'

ipap_rate = pd.read_excel(path+file_name)
ipap_rate = ipap_rate.drop('Unnamed: 0', axis=1)
ipap_rate.head()
# Out:
#        category   value       date
# 0  Total tarifa  159.83 2022-06-01
# 1  Total tarifa  188.44 2022-05-01
# 2  Total tarifa  157.63 2022-04-01
# 3  Total tarifa  132.17 2022-03-01
# 4  Total tarifa  133.25 2022-02-01

# %%
ipap_rate_summary = describe_df(ipap_rate)
# Out:
# Shape of dataframe is:
# (840, 3)
#
# Data types of dataframe are:
# category            object
# value              float64
# date        datetime64[ns]
# dtype: object
#
# Summary of numeric data is:
#        count      mean        std  min     25%     50%       75%     max
# value  840.0  119.5315  19.128604  0.0  107.43  114.85  128.0925  227.61
#
# Summary of categorical data is:
#          count unique           top freq
# category   840      4  Total tarifa  210
#
# Does it contain missing values?
# category    0
# value       0
# date        0
# dtype: int64
#
# Value counts:
# Total tarifa            210
# Tarifa normal           210
# Tarifa fin de semana    210
# Tarifa touroperador     210
# Name: category, dtype: int64
#
# 0.00      4
# 109.15    3
# 107.36    3
# 104.48    3
# 108.51    3
#          ..
# 126.58    1
# 117.11    1
# 112.58    1
# 99.66     1
# 100.23    1
# Name: value, Length: 757, dtype: int64
#
# 2022-06-01    4
# 2009-05-01    4
# 2011-05-01    4
# ...

# %%
ipap_rate_hist = create_histograms(ipap_rate, 'category', 'value')

# %%
ipap_rate_boxplot = create_boxplots(ipap_rate, 'category', 'value')
# Out:
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ameli\anaconda3\envs\Midbootcamp\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
fig, ax = plt.subplots(dpi=200)
ax = sns.lineplot(data= ipap_rate, x= 'date', y = 'value', hue = 'category', style = 'category')
ax = plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()
